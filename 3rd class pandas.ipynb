# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("astronauts.csv")

# %%
data.shape
# Out:
# (357, 19)

# %%
data.ndim
# Out:
# 2

# %%
data.columns
# Out:
# Index(['Name', 'Year', 'Group', 'Status', 'Birth Date', 'Birth Place',
#        'Gender', 'Alma Mater', 'Undergraduate Major', 'Graduate Major',
#        'Military Rank', 'Military Branch', 'Space Flights',
#        'Space Flight (hr)', 'Space Walks', 'Space Walks (hr)', 'Missions',
#        'Death Date', 'Death Mission'],
#       dtype='object')

# %%
#changing columns names
#data.columns = [11,22,33,44,55,66,77,88,99,100, 111,222,333,444,555,666,777,888,999]

# %%
data.head()
# Out:
#                Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0   Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# 1    Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
# 2  James C. Adamson  1984.0   10.0  Retired   3/3/1946     Warsaw, NY   Male
# 3   Thomas D. Akers  1987.0   12.0  Retired  5/20/1951  St. Louis, MO   Male
# 4       Buzz Aldrin  1963.0    3.0  Retired  1/20/1930  Montclair, NJ   Male
#
#                                           Alma Mater     Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...                 Geology
# 1   Montana State University; University of Colorado     Engineering Physics
# 2          US Military Academy; Princeton University             Engineering
# 3                       University of Missouri-Rolla     Applied Mathematics
# 4                           US Military Academy; MIT  Mechanical Engineering
#
# ...

# %%
data.columns
# Out:
# Index(['Name', 'Year', 'Group', 'Status', 'Birth Date', 'Birth Place',
#        'Gender', 'Alma Mater', 'Undergraduate Major', 'Graduate Major',
#        'Military Rank', 'Military Branch', 'Space Flights',
#        'Space Flight (hr)', 'Space Walks', 'Space Walks (hr)', 'Missions',
#        'Death Date', 'Death Mission'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['Name', 'Year', 'Group', 'Status', 'Birth Date', 'Birth Place',
#        'Gender', 'Alma Mater', 'Undergraduate Major', 'Graduate Major',
#        'Military Rank', 'Military Branch', 'Space Flights',
#        'Space Flight (hr)', 'Space Walks', 'Space Walks (hr)', 'Missions',
#        'Death Date', 'Death Mission'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 357 non-null    object
#  1   Year                 330 non-null    float64
#  2   Group                330 non-null    float64
#  3   Status               357 non-null    object
#  4   Birth Date           357 non-null    object
#  5   Birth Place          357 non-null    object
#  6   Gender               357 non-null    object
#  7   Alma Mater           356 non-null    object
#  8   Undergraduate Major  335 non-null    object
#  9   Graduate Major       298 non-null    object
#  10  Military Rank        207 non-null    object
#  11  Military Branch      211 non-null    object
#  12  Space Flights        357 non-null    int64
#  13  Space Flight (hr)    357 non-null    int64
#  14  Space Walks          357 non-null    int64
# ...

# %%
data.isnull()
# Out:
#       Name   Year  Group  Status  Birth Date  Birth Place  Gender  Alma Mater  \
# 0    False  False  False   False       False        False   False       False
# 1    False   True   True   False       False        False   False       False
# 2    False  False  False   False       False        False   False       False
# 3    False  False  False   False       False        False   False       False
# 4    False  False  False   False       False        False   False       False
# ..     ...    ...    ...     ...         ...          ...     ...         ...
# 352  False  False  False   False       False        False   False       False
# 353  False  False  False   False       False        False   False       False
# 354  False  False  False   False       False        False   False       False
# 355  False  False  False   False       False        False   False       False
# 356  False  False  False   False       False        False   False       False
#
# ...

# %%
data.notnull()
# Out:
#      Name   Year  Group  Status  Birth Date  Birth Place  Gender  Alma Mater  \
# 0    True   True   True    True        True         True    True        True
# 1    True  False  False    True        True         True    True        True
# 2    True   True   True    True        True         True    True        True
# 3    True   True   True    True        True         True    True        True
# 4    True   True   True    True        True         True    True        True
# ..    ...    ...    ...     ...         ...          ...     ...         ...
# 352  True   True   True    True        True         True    True        True
# 353  True   True   True    True        True         True    True        True
# 354  True   True   True    True        True         True    True        True
# 355  True   True   True    True        True         True    True        True
# 356  True   True   True    True        True         True    True        True
#
# ...

# %%
data[data.isnull()]
# Out:
#     Name  Year  Group Status Birth Date Birth Place Gender Alma Mater  \
# 0    NaN   NaN    NaN    NaN        NaN         NaN    NaN        NaN
# 1    NaN   NaN    NaN    NaN        NaN         NaN    NaN        NaN
# 2    NaN   NaN    NaN    NaN        NaN         NaN    NaN        NaN
# 3    NaN   NaN    NaN    NaN        NaN         NaN    NaN        NaN
# 4    NaN   NaN    NaN    NaN        NaN         NaN    NaN        NaN
# ..   ...   ...    ...    ...        ...         ...    ...        ...
# 352  NaN   NaN    NaN    NaN        NaN         NaN    NaN        NaN
# 353  NaN   NaN    NaN    NaN        NaN         NaN    NaN        NaN
# 354  NaN   NaN    NaN    NaN        NaN         NaN    NaN        NaN
# 355  NaN   NaN    NaN    NaN        NaN         NaN    NaN        NaN
# 356  NaN   NaN    NaN    NaN        NaN         NaN    NaN        NaN
#
#     Undergraduate Major Graduate Major Military Rank Military Branch  \
# ...

# %%
data.isnull().sum()#tell us quality of data
# Out:
# Name                     0
# Year                    27
# Group                   27
# Status                   0
# Birth Date               0
# Birth Place              0
# Gender                   0
# Alma Mater               1
# Undergraduate Major     22
# Graduate Major          59
# Military Rank          150
# Military Branch        146
# Space Flights            0
# Space Flight (hr)        0
# Space Walks              0
# Space Walks (hr)         0
# Missions                23
# Death Date             305
# Death Mission          341
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Name                   357
# Year                   330
# Group                  330
# Status                 357
# Birth Date             357
# Birth Place            357
# Gender                 357
# Alma Mater             356
# Undergraduate Major    335
# Graduate Major         298
# Military Rank          207
# Military Branch        211
# Space Flights          357
# Space Flight (hr)      357
# Space Walks            357
# Space Walks (hr)       357
# Missions               334
# Death Date              52
# Death Mission           16
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 357 non-null    object
#  1   Year                 330 non-null    float64
#  2   Group                330 non-null    float64
#  3   Status               357 non-null    object
#  4   Birth Date           357 non-null    object
#  5   Birth Place          357 non-null    object
#  6   Gender               357 non-null    object
#  7   Alma Mater           356 non-null    object
#  8   Undergraduate Major  335 non-null    object
#  9   Graduate Major       298 non-null    object
#  10  Military Rank        207 non-null    object
#  11  Military Branch      211 non-null    object
#  12  Space Flights        357 non-null    int64
#  13  Space Flight (hr)    357 non-null    int64
#  14  Space Walks          357 non-null    int64
# ...

# %%
data.Year
# Out:
# 0      2004.0
# 1         NaN
# 2      1984.0
# 3      1987.0
# 4      1963.0
#         ...
# 352    1990.0
# 353    1998.0
# 354    1966.0
# 355    1962.0
# 356    1998.0
# Name: Year, Length: 357, dtype: float64

# %%
data.Year = pd.to_datetime(data.Year)
data.Year
# Out:
# 0     1970-01-01 00:00:00.000002004
# 1                               NaT
# 2     1970-01-01 00:00:00.000001984
# 3     1970-01-01 00:00:00.000001987
# 4     1970-01-01 00:00:00.000001963
#                    ...
# 352   1970-01-01 00:00:00.000001990
# 353   1970-01-01 00:00:00.000001998
# 354   1970-01-01 00:00:00.000001966
# 355   1970-01-01 00:00:00.000001962
# 356   1970-01-01 00:00:00.000001998
# Name: Year, Length: 357, dtype: datetime64[ns]

# %%
data.Birth Date= pd.to_datetime(data.Birth Date)
# Out:
#   File "C:\Users\Leo\AppData\Local\Temp/ipykernel_9456/926040276.py", line 1
#     data.Birth Date= pd.to_datetime(data.Birth Date)
#                ^
# SyntaxError: invalid syntax

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 357 non-null    object
#  1   Year                 330 non-null    datetime64[ns]
#  2   Group                330 non-null    float64
#  3   Status               357 non-null    object
#  4   Birth Date           357 non-null    object
#  5   Birth Place          357 non-null    object
#  6   Gender               357 non-null    object
#  7   Alma Mater           356 non-null    object
#  8   Undergraduate Major  335 non-null    object
#  9   Graduate Major       298 non-null    object
#  10  Military Rank        207 non-null    object
#  11  Military Branch      211 non-null    object
#  12  Space Flights        357 non-null    int64
#  13  Space Flight (hr)    357 non-null    int64
#  14  Space Walks          357 non-null    int64
# ...

# %%
#data.Year.astypt('int 32')

# %%
data.Status.value_counts()
# Out:
# Retired       220
# Deceased       51
# Active         50
# Management     36
# Name: Status, dtype: int64

# %%
data.Alma Mater.value_counts()
# Out:
#   File "C:\Users\Leo\AppData\Local\Temp/ipykernel_9456/2375893056.py", line 1
#     data.Alma Mater.value_counts()
#               ^
# SyntaxError: invalid syntax

# %%
data.Alma Mater.unique()
# Out:
#   File "C:\Users\Leo\AppData\Local\Temp/ipykernel_9456/3449539000.py", line 1
#     data.Alma Mater.unique()
#               ^
# SyntaxError: invalid syntax

# %%
pd.series([1,3,4,56,78,87,78]).unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9456/1557561455.py in <module>
# ----> 1 pd.series([1,3,4,56,78,87,78]).unique()
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'series'

# %%
data.isnull()
# Out:
#       Name   Year  Group  Status  Birth Date  Birth Place  Gender  Alma Mater  \
# 0    False  False  False   False       False        False   False       False
# 1    False   True   True   False       False        False   False       False
# 2    False  False  False   False       False        False   False       False
# 3    False  False  False   False       False        False   False       False
# 4    False  False  False   False       False        False   False       False
# ..     ...    ...    ...     ...         ...          ...     ...         ...
# 352  False  False  False   False       False        False   False       False
# 353  False  False  False   False       False        False   False       False
# 354  False  False  False   False       False        False   False       False
# 355  False  False  False   False       False        False   False       False
# 356  False  False  False   False       False        False   False       False
#
# ...

# %%
data.Year
# Out:
# 0     1970-01-01 00:00:00.000002004
# 1                               NaT
# 2     1970-01-01 00:00:00.000001984
# 3     1970-01-01 00:00:00.000001987
# 4     1970-01-01 00:00:00.000001963
#                    ...
# 352   1970-01-01 00:00:00.000001990
# 353   1970-01-01 00:00:00.000001998
# 354   1970-01-01 00:00:00.000001966
# 355   1970-01-01 00:00:00.000001962
# 356   1970-01-01 00:00:00.000001998
# Name: Year, Length: 357, dtype: datetime64[ns]

# %% [markdown]
# # handling missing values
#     #Filling missing values
#     dropping missing values

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 357 non-null    object
#  1   Year                 330 non-null    datetime64[ns]
#  2   Group                330 non-null    float64
#  3   Status               357 non-null    object
#  4   Birth Date           357 non-null    object
#  5   Birth Place          357 non-null    object
#  6   Gender               357 non-null    object
#  7   Alma Mater           356 non-null    object
#  8   Undergraduate Major  335 non-null    object
#  9   Graduate Major       298 non-null    object
#  10  Military Rank        207 non-null    object
#  11  Military Branch      211 non-null    object
#  12  Space Flights        357 non-null    int64
#  13  Space Flight (hr)    357 non-null    int64
#  14  Space Walks          357 non-null    int64
# ...

# %%
data.Year=data.Year.fillna(data.Year.mode(),inplace=True)
data.Year.mode()
# Out:
# Series([], dtype: object)

# %%
data.Year.isnull().sum()
# Out:
# 357

# %%
data.fillna({'Year': data.Year.mode(),
            'Group': data.Group.mode(),
            'Alma Mater':data.Alma Mater.mode(),
            'Undergraduate Major': data.Undergraduate Major.mode(),
            })
